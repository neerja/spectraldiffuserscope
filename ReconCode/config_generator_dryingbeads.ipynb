# %% [markdown]
# # Import the necessary packages and helper functions

# %%
import torch
import sdc_jax as sdc 
import os
import matplotlib.pyplot as plt
import yaml

def adjust_indices(indices, factor):
    top, bottom, left, right = indices
    
    # Ensure indices are divisible by the downsample factor
    if top % factor != 0:
        top -= factor - (top % factor)
    if bottom % factor != 0:
        bottom += bottom % factor
    if left % factor != 0:
        left -= factor - (left % factor)
    if right % factor != 0:
        right += right % factor
    
    # Ensure the height and width are even after downsampling
    height = bottom - top
    width = right - left
    
    if (height // factor) % 2 != 0:
        bottom += factor  # Adjust to make the height even
    if (width // factor) % 2 != 0:
        right += factor  # Adjust to make the width even
    
    return [top, bottom, left, right]

# %% [markdown]
# # Define all of your parameters

# %%
# Define the paths to the calibration files
calibration_folder_location = "/home/neerja/CODE/SpectralDiffuserScopeGitRepo/JaxCode/Calibration_data"

# Provide the name of the calibration files to be used
psf_name = "psf_2024-01-30.pt"
calibration_wavelengths_file = "wavelengths_2024-02-28.npy"
filter_cube_file = "spectral_filter_2024-02-28.npy"

# Define the path to the data file
datafolder = '/media/azuldata/neerja/2024-02-01/drying_beads_drop/meas0000'
sample = datafolder.split("/")[-2] # NOTE changed from -1 to -2

# Define some parameters for measurement processing
bits = 16
crop_indices = [420,1852,1450,2826] # [top, bottom, left, right]
wvmin = 450
wvmax = 700
wvstep = 8
downsample_factor = 1

# Adjust crop indices to make sure they are divisible by downsample factor and even after downsampling
crop_indices = adjust_indices(crop_indices, downsample_factor)

# Define some reconstruction parameters
kmax = 1000
step_size = 0.25
thr = 6e-4
xytv = 0
lamtv = 2e-6 
use_low_rank = False
use_one_hot = True
rank = 3 # number of components expected in image

# Define some WandB parameters
kprint = 100
project_name = "HyperSpectralDiffuserScope"
# run_name = "one_hot_test"
run_name = sample + '_thr={}_xytv={}_lamtv={}_kmax={}_stepsize={}_downsample={}'.format(thr, xytv, lamtv, kmax, step_size, downsample_factor)
save_location = '/home/neerja/CODE/SpectralDiffuserScopeGitRepo/JaxCode/Results'
save_frequency = 1e6 # don't really use

# config_file_path = "./Config_Files/config_"+sample+".yaml"
config_file_path = "./Config_Files/dryingbeadsdrop/config_2024-02-01_dryingbeadsdrop.yaml"

# %% [markdown]
# # Make sure you have selected the correct ROI

# %%
# Load the measurement
try:
    sample_meas = sdc.importTiff(datafolder,'meas.tiff')/(2**bits-1)
except:
    sample_meas = torch.mean(sdc.tif_loader(os.path.join(datafolder,'measurements'))/(2**bits-1),0)
try:
    background = sdc.importTiff(datafolder,'bg.tiff')/2**bits
except:
    print('No background image found, continuing without background subtraction')
    background = torch.zeros(sample_meas.shape)

# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

meas = sample_meas - background
#set negative values to 0
meas[meas<0] = 0
# First subplot: Measurement with ROI outlined
ax[0].imshow(meas**.5, cmap='gray')
ax[0].plot([crop_indices[2], crop_indices[3]], [crop_indices[0], crop_indices[0]], 'r')
ax[0].plot([crop_indices[2], crop_indices[3]], [crop_indices[1], crop_indices[1]], 'r')
ax[0].plot([crop_indices[2], crop_indices[2]], [crop_indices[0], crop_indices[1]], 'r')
ax[0].plot([crop_indices[3], crop_indices[3]], [crop_indices[0], crop_indices[1]], 'r')
ax[0].set_title('Measurement with ROI')
ax[0].grid()

# Second subplot: ROI with original axis labels
roi = meas[crop_indices[0]:crop_indices[1], crop_indices[2]:crop_indices[3]]
ax[1].imshow(roi**.5, cmap='gray', extent=[crop_indices[2], crop_indices[3], crop_indices[1], crop_indices[0]])
ax[1].set_title('Cropped ROI')
ax[1].set_xlabel('X-axis (original location)')
ax[1].set_ylabel('Y-axis (original location)')
ax[1].grid()

# Show the figure
plt.show()

# %% [markdown]
# # Save everything as a config file

# %%
for k in range(24):
    datafolder = f'/media/azuldata/neerja/2024-02-01/drying_beads_drop/meas{k:04d}'
    config_file_path = f"./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_{k:04d}.yaml"
    run_name = f"dryingbeadsdrop_{k:04d}"
    config = {
        "calibration": {
            "folder_location": calibration_folder_location,
            "psf_name": psf_name,
            "calibration_wavelengths_file": calibration_wavelengths_file,
            "filter_cube_file": filter_cube_file
        },
        "data": {
            "datafolder": datafolder,
            "sample": sample
        },
        "measurement_processing": {
            "bits": bits,
            "crop_indices": crop_indices,
            "wvmin": wvmin,
            "wvmax": wvmax,
            "wvstep": wvstep,
            "downsample_factor": downsample_factor
        },
        "reconstruction": {
            "kmax": kmax,
            "step_size": step_size,
            "thr": thr,
            "xytv": xytv,
            "lamtv": lamtv,
            "use_low_rank": use_low_rank,
            "use_one_hot": use_one_hot,
            "rank": rank
        },
        "wandb": {
            "kprint": kprint,
            "project_name": project_name,
            "run_name": run_name,
            "save_location": save_location,
            "save_frequency": save_frequency
        }
    }

    # Save the configuration to a YAML file
    with open(config_file_path, 'w') as config_file:
        yaml.dump(config, config_file, default_flow_style=False)

    print(f"Configuration saved to {config_file_path}")
# Out:
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0000.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0001.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0002.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0003.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0004.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0005.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0006.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0007.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0008.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0009.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0010.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0011.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0012.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0013.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0014.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0015.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0016.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0017.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0018.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0019.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0020.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0021.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0022.yaml
# Configuration saved to ./Config_Files/dryingbeadsdrop_2024-02-01/config_dryingbeadsdrop_0023.yaml
